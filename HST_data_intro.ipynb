# %%
testfile = 'SDSS-J120639.85+025308.3.cat'

from astropy.io import ascii
testdat = ascii.read(testfile)

# %%
print testdat
# Out:
# NUMBER X_IMAGE  Y_IMAGE    X_WORLD    ... FLUX_RADIUS FLUX_RADIUS2 CLASS_STAR
#          pix      pix        deg      ...     pix         pix
# ------ -------- -------- ------------ ... ----------- ------------ ----------
#      1 2416.579  548.277 181.65618383 ...       4.772        9.908       0.03
#      2  2416.51    539.0 181.65618497 ...       4.233        5.428        0.2
#      3 2205.662  564.287 181.65970351 ...       4.939        8.311        0.0
#      4 2342.396  619.583 181.65742175 ...       8.858        18.89        0.0
#      5 2597.944  1321.23 181.65315715 ...      24.916       86.373       0.03
#      6 2413.234  598.196 181.65623964 ...       2.509        6.185       0.03
#      7 2441.965    594.5 181.65576019 ...       3.137        5.492        0.0
#      8 2266.896  601.026 181.65868167 ...       3.167         7.32       0.03
#      9 2346.669  638.408 181.65735044 ...      10.435       14.039       0.03
# ...

# %%
## read in the star classification column into an array called star_prob
star_prob = testdat['CLASS_STAR']


## Here are two different ways you might go through each item in the array 
## and check to see if it meets a particular condition (e.g., is likely to be a star):


## Method 1:
#for s in range(0,len(star_prob)):
#    print s, star_prob
#    if star_prob[s]>0.9:
#        print "probably a star!"
    
## Method 2:    
counter=-1    # arrays in python are always indexed starting with zero
for star in star_prob:
    counter+=1
    print counter, star_prob[counter]
    if float(star)>0.9:
        print "probably a star!"
# Out:
# 0 0.03
# 1 0.2
# 2 0.0
# 3 0.0
# 4 0.03
# 5 0.03
# 6 0.0
# 7 0.03
# 8 0.03
# 9 0.0
# 10 0.0
# 11 0.0
# 12 0.0
# 13 0.02
# 14 0.0
# 15 0.0
# 16 0.03
# 17 0.0
# 18 0.0
# 19 0.01
# 20 0.0
# 21 0.02
# 22 0.0
# 23 0.0
# 24 0.0
# 25 0.0
# 26 0.0
# 27 0.0
# 28 0.0
# 29 0.0
# 30 0.0
# 31 0.61
# 32 0.0
# 33 0.03
# 34 0.0
# 35 0.0
# 36 0.0
# 37 0.0
# 38 0.21
# 39 0.0
# 40 0.01
# 41 0.0
# 42 0.0
# 43 0.0
# 44 0.03
# 45 0.0
# 46 0.0
# 47 0.0
# 48 0.01
# 49 0.0
# 50 0.0
# 51 0.0
# 52 0.0
# 53 0.0
# 54 0.0
# 55 0.0
# 56 0.0
# 57 0.94
# probably a star!
# 58 0.03
# 59 0.0
# 60 0.03
# 61 0.44
# 62 0.0
# 63 0.0
# 64 0.0
# 65 0.0
# 66 0.01
# 67 0.0
# 68 0.0
# 69 0.01
# 70 0.92
# probably a star!
# 71 0.03
# 72 0.0
# 73 0.83
# 74 0.03
# 75 0.03
# 76 0.0
# 77 0.0
# 78 0.0
# 79 0.0
# 80 0.0
# 81 0.0
# 82 0.0
# 83 0.0
# 84 0.0
# 85 0.0
# 86 0.02
# 87 0.0
# 88 0.03
# 89 0.0
# 90 0.0
# 91 0.0
# 92 0.03
# 93 0.03
# 94 0.0
# 95 0.0
# 96 0.0
# 97 0.0
# 98 0.0
# 99 0.45
# 100 0.0
# 101 0.0
# 102 0.0
# 103 0.0
# ...
